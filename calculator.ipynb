# %%
import math

def solve_proportion(a, b, c):
    """Solves a proportion of the form a/b = c/x and returns the value of x."""
    x = (b * c) / a
    return x

def solve_equation(equation):
    """Solves an equation of the form 'x + a = b' and returns the value of x."""
    parts = equation.split('=')
    left_side = parts[0].strip()
    right_side = parts[1].strip()
    x = float(right_side) - float(left_side)
    return x

def factor_square_root(n):
    """Factors a square root and returns the simplified form."""
    factors = []
    sqrt = math.sqrt(n)
    for i in range(2, int(sqrt) + 1):
        while n % (i * i) == 0:
            factors.append(i)
            n //= (i * i)
    if n > 1:
        factors.append(n)
    return '√' + '√'.join(str(factor) for factor in factors)

def convert_decimal_to_fraction(decimal):
    """Converts a decimal to a fraction and returns the simplified form."""
    fraction = fractions.Fraction(decimal).limit_denominator()
    return f"{fraction.numerator}/{fraction.denominator}"

def convert_decimal_to_percent(decimal):
    """Converts a decimal to a percent."""
    percent = decimal * 100
    return f"{percent}%"

def convert_fraction_to_decimal(fraction):
    """Converts a fraction to a decimal."""
    numerator, denominator = map(int, fraction.split('/'))
    decimal = numerator / denominator
    return decimal

def convert_fraction_to_percent(fraction):
    """Converts a fraction to a percent."""
    numerator, denominator = map(int, fraction.split('/'))
    percent = (numerator / denominator) * 100
    return f"{percent}%"

def convert_percent_to_decimal(percent):
    """Converts a percent to a decimal."""
    decimal = float(percent.strip('%')) / 100
    return decimal

def convert_percent_to_fraction(percent):
    """Converts a percent to a fraction."""
    decimal = float(percent.strip('%')) / 100
    fraction = fractions.Fraction(decimal).limit_denominator()
    return f"{fraction.numerator}/{fraction.denominator}"

# Main program loop
while True:
    print("1. Solve Proportions")
    print("2. Solve for x in Equations")
    print("3. Factor Square Roots")
    print("4. Convert Decimals to Fractions and Percents")
    print("5. Convert Fractions to Decimals and Percents")
    print("6. Convert Percents to Decimals and Fractions")
    print("0. Exit")
    choice = input("Enter your choice (0-6): ")

    if choice == '0':
        break

    if choice == '1':
        a = float(input("Enter value for a: "))
        b = float(input("Enter value for b: "))
        c = float(input("Enter value for c: "))
        result = solve_proportion(a, b, c)
        print(f"The value of x is: {result}")

    elif choice == '2':
        equation = input("Enter the equation (e.g., 'x + a = b'): ")
        result = solve_equation(equation)
        print(f"The value of x is: {result}")

    elif choice == '3':
        n = int(input("Enter the number: "))
        result = factor_square_root(n)
        print(f"The factorized square root is: {result}")

    elif choice == '4':
        decimal = float(input("Enter the decimal number: "))
        fraction = convert_decimal_to_fraction(decimal)
        percent = convert_decimal_to_percent(decimal)
        print(f"The decimal as a fraction: {fraction}")
        print(f"The decimal as a percent: {percent}")

    elif choice == '5':
        fraction = input("Enter the fraction (e.g., '2/5'): ")
        decimal = convert_fraction_to_decimal(fraction)
        percent = convert_fraction_to_percent(fraction)
        print(f"The fraction as a decimal: {decimal}")
        print(f"The fraction as a percent: {percent}")

    elif choice == '6':
        percent = input("Enter the percent (e.g., '75%'): ")
        decimal = convert_percent_to_decimal(percent)
        fraction = convert_percent_to_fraction(percent)
        print(f"The percent as a decimal: {decimal}")
        print(f"The percent as a fraction: {fraction}")

    else:
        print("Invalid choice. Please try again.\n")
